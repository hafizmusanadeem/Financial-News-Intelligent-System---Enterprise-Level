# %%
df = pd.read_csv(
    r'C:\Users\DELL\Documents\MLOPS\Finance News Intelligent System\Financial-News-Intelligent-System---Enterprise-Level\artifacts\interim\news_data.csv'
)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ticker', 'title', 'summary', 'source', 'source_domain',
#        'time_published', 'overall_sentiment_score', 'overall_sentiment_label'],
#       dtype='object')

# %%
df.drop(columns=['source_domain', 'Unnamed: 0'], inplace=True, errors='ignore')

# %%
df.columns
# Out:
# Index(['ticker', 'title', 'summary', 'source', 'time_published',
#        'overall_sentiment_score', 'overall_sentiment_label'],
#       dtype='object')

# %%
df.shape
# Out:
# (462, 7)

# %% [markdown]
# # **Labelled_Data**

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Documents\MLOPS\Finance News Intelligent System\Financial-News-Intelligent-System---Enterprise-Level\artifacts\interim\news_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 ticker                                              title  \
# 0           0   AAPL  Consumer Discretionary Stocks Q3 Teardown: App...
# 1           1   AAPL  【即時新聞】FT Vest U.S. Equity Buffer & Premium Inc...
# 2           2   AAPL  Apple stock heads into Monday under a valuatio...
# 3           3   AAPL  At CES, Mercedes-Benz CLA Features Xperi Video...
# 4           4   AAPL  Apple stock starts 2026 on a slip as valuation...
#
#                                              summary       source  \
# 0  This article provides a Q3 teardown of consume...       Finviz
# 1  FT Vest U.S. Equity Buffer & Premium Income ET...          理財寶
# 2  Raymond James has initiated coverage on Apple ...     ts2.tech
# 3  Mercedes-Benz is showcasing its new CLA electr...  Radio World
# 4  Apple Inc. (AAPL.O) shares closed down 0.31% a...     ts2.tech
#
#   source_domain       time_published  overall_sentiment_score  \
# 0        Finviz  2026-01-04 22:34:00                 0.273852
# 1           理財寶  2026-01-04 22:09:17                 0.061261
# 2      ts2.tech  2026-01-04 21:55:33                 0.084988
# 3   Radio World  2026-01-04 18:08:56                 0.201609
# 4      ts2.tech  2026-01-04 15:09:26                 0.114468
#
#   overall_sentiment_label
# 0        Somewhat-Bullish
# 1                 Neutral
# 2                 Neutral
# 3        Somewhat-Bullish
# 4                 Neutral

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'ticker',
#  'title',
#  'summary',
#  'source',
#  'source_domain',
#  'time_published',
#  'overall_sentiment_score',
#  'overall_sentiment_label']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               462 non-null    int64
#  1   ticker                   462 non-null    object
#  2   title                    462 non-null    object
#  3   summary                  462 non-null    object
#  4   source                   462 non-null    object
#  5   source_domain            462 non-null    object
#  6   time_published           462 non-null    object
#  7   overall_sentiment_score  462 non-null    float64
#  8   overall_sentiment_label  462 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage:
# 2025-03-26 04:58:00
# 2025-03-24 10:17:00
# 2025-03-21 03:37:50
# 2025-03-20 03:55:21
# 2025-03-20 03:50:17
# 2025-03-20 03:22:00
# 2025-03-19 03:55:21
# 2025-03-14 03:55:22
# 2025-03-13 08:36:00
# 2025-03-13 05:10:26
# 2025-03-09 02:50:43
# 2025-03-06 10:15:00
# 2025-03-27 11:00:00
# 2025-03-27 09:29:00
# 2025-03-26 02:50:36
# 2025-03-20 09:23:00
# 2025-03-18 02:31:36
# 2025-03-14 03:33:03
# 2025-03-12 03:52:42
# 2025-03-12 03:08:58
# 2025-03-06 17:24:00
# 2025-03-06 03:51:30
# 2025-03-06 03:00:49
# 2025-03-04 17:38:00
# 2025-03-03 05:00:00
# 2025-03-02 03:52:42
# 2025-02-27 05:14:13
# 2025-02-25 05:14:13
# 2025-02-21 05:14:13
# 2025-02-21 04:32:22
# 2025-02-20 04:33:21
# 2025-02-19 04:33:21
# 2025-03-31 14:52:44
# 2025-03-24 12:46:00
# 2025-03-19 12:47:00
# 2025-03-19 11:18:00
# 2025-03-18 03:56:23
# 2025-03-17 23:08:00
# 2025-03-17 11:39:00
# 2025-03-11 11:09:30
# 2025-03-09 12:51:17
# 2025-03-01 03:56:23
# 2025-02-28 21:07:00
# 2025-03-31 02:50:58
# 2025-03-21 19:47:00
# 2025-03-20 04:24:00
# 2025-03-20 02:33:35
# 2025-03-17 03:08:00
# 2025-03-16 23:50:00
# 2025-03-12 02:50:58
# 2025-03-05 03:06:36
# 2025-03-04 03:03:57
# 2025-02-28 15:31:00
# 2025-02-27 01:33:00
# 2025-02-27 01:07:00

# %% [markdown]
# # **Impact Score**

# %%
df_ = pd.read_csv(r"C:\Users\DELL\Documents\MLOPS\Finance News Intelligent System\Financial-News-Intelligent-System---Enterprise-Level\artifacts\transform\impact_score\next_day_news_with_stock_prices.csv")

# %%
len(df_.columns.tolist())
# Out:
# 16

# %%
df_.columns.tolist()
# Out:
# ['ticker',
#  'time_published',
#  'news_date',
#  'day0_close',
#  'day1_close',
#  'next_day_return',
#  'impact_score',
#  'impact_label',
#  '_1',
#  'title',
#  'summary',
#  'source',
#  'source_domain',
#  'overall_sentiment_score',
#  'overall_sentiment_label',
#  'event_label']

# %%
df_.day0_close.isnull().sum()
# Out:
# np.int64(246)

# %%
df_.day0_close
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 457    150.809998
# 458    152.000000
# 459    158.619995
# 460    156.669998
# 461    156.669998
# Name: day0_close, Length: 462, dtype: float64

# %%
df_['event_label'].unique()
# Out:
# array(['Earnings', 'Market Movement', 'Product Launch', 'Other',
#        'Regulatory/Legal', 'Merger/Acquisition', 'Leadership Change',
#        'Economic Data', 'Fed Monetary Policy'], dtype=object)
