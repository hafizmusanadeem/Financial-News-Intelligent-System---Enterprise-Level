# %%
df = pd.read_csv(
    r'C:\Users\DELL\Documents\MLOPS\Finance News Intelligent System\Financial-News-Intelligent-System---Enterprise-Level\artifacts\interim\news_data.csv'
)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ticker', 'title', 'summary', 'source', 'source_domain',
#        'time_published', 'overall_sentiment_score', 'overall_sentiment_label'],
#       dtype='object')

# %%
df.drop(columns=['source_domain', 'Unnamed: 0'], inplace=True, errors='ignore')

# %%
df.columns
# Out:
# Index(['ticker', 'title', 'summary', 'source', 'time_published',
#        'overall_sentiment_score', 'overall_sentiment_label'],
#       dtype='object')

# %%
df.shape
# Out:
# (462, 7)

# %% [markdown]
# # **Labelled_Data**

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Documents\MLOPS\Finance News Intelligent System\Financial-News-Intelligent-System---Enterprise-Level\artifacts\interim\news_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 ticker                                              title  \
# 0           0   AAPL  Consumer Discretionary Stocks Q3 Teardown: App...
# 1           1   AAPL  【即時新聞】FT Vest U.S. Equity Buffer & Premium Inc...
# 2           2   AAPL  Apple stock heads into Monday under a valuatio...
# 3           3   AAPL  At CES, Mercedes-Benz CLA Features Xperi Video...
# 4           4   AAPL  Apple stock starts 2026 on a slip as valuation...
#
#                                              summary       source  \
# 0  This article provides a Q3 teardown of consume...       Finviz
# 1  FT Vest U.S. Equity Buffer & Premium Income ET...          理財寶
# 2  Raymond James has initiated coverage on Apple ...     ts2.tech
# 3  Mercedes-Benz is showcasing its new CLA electr...  Radio World
# 4  Apple Inc. (AAPL.O) shares closed down 0.31% a...     ts2.tech
#
#   source_domain       time_published  overall_sentiment_score  \
# 0        Finviz  2026-01-04 22:34:00                 0.273852
# ...

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'ticker',
#  'title',
#  'summary',
#  'source',
#  'source_domain',
#  'time_published',
#  'overall_sentiment_score',
#  'overall_sentiment_label']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               462 non-null    int64
#  1   ticker                   462 non-null    object
#  2   title                    462 non-null    object
#  3   summary                  462 non-null    object
#  4   source                   462 non-null    object
#  5   source_domain            462 non-null    object
#  6   time_published           462 non-null    object
#  7   overall_sentiment_score  462 non-null    float64
#  8   overall_sentiment_label  462 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 32.6+ KB

# %%
df['ticker'].unique()
# Out:
# array(['AAPL', 'AMZN', 'MSFT', 'GOOGL', 'NVDA', 'META', 'TSLA', 'JPM',
#        'V', 'JNJ', 'BAC', 'WMT', 'UNH', 'XOM', 'CVX'], dtype=object)

# %%
df.drop(columns=['source_domain'], inplace=True)

# %%
df['time_published'] = pd.to_datetime(df['time_published'])

# %%
start = df['time_published'].min()
end = df['time_published'].max()
print(f"Start: {start}, End: {end}")
# Out:
# Start: 2025-01-10 18:24:00, End: 2026-01-04 23:41:00

# %%
for i in range(325,462):
    print(df['time_published'].iloc[i])
# Out:
# 2025-03-12 00:00:00
# 2025-03-11 00:00:00
# 2025-03-07 16:51:00
# 2025-03-07 14:10:00
# 2025-03-07 10:32:00
# 2025-03-06 08:59:00
# 2025-03-06 03:31:54
# 2025-03-31 11:39:50
# 2025-03-31 03:14:37
# 2025-03-31 02:09:50
# 2025-03-28 22:09:18
# 2025-03-28 15:23:00
# 2025-03-28 03:55:38
# 2025-03-28 03:44:32
# 2025-03-27 09:15:00
# 2025-03-26 07:00:00
# 2025-03-21 03:51:22
# 2025-03-20 16:05:00
# 2025-03-20 14:09:35
# 2025-03-20 03:51:32
# 2025-03-19 00:00:00
# 2025-03-18 02:37:01
# 2025-03-17 11:10:00
# 2025-03-31 03:12:44
# 2025-03-31 03:01:28
# 2025-03-30 18:10:43
# 2025-03-30 09:50:00
# 2025-03-29 08:55:00
# 2025-03-27 21:20:00
# 2025-03-27 03:55:02
# 2025-03-26 12:00:00
# 2025-03-26 02:33:03
# 2025-03-25 22:52:27
# 2025-03-24 22:11:01
# 2025-03-21 18:09:12
# 2025-03-21 13:39:00
# 2025-03-21 05:09:25
# 2025-03-21 19:16:00
# 2025-03-14 17:14:00
# 2025-03-11 10:54:00
# 2025-03-04 17:34:00
# 2025-02-18 05:11:39
# 2025-02-18 05:05:26
# 2025-02-03 05:15:11
# 2025-02-03 04:38:40
# ...

# %% [markdown]
# # **Impact Score**

# %%
df_ = pd.read_csv(r"C:\Users\DELL\Documents\MLOPS\Finance News Intelligent System\Financial-News-Intelligent-System---Enterprise-Level\artifacts\transform\impact_score\impact_scores.csv")

# %%
len(df_.columns.tolist())
# Out:
# 22

# %%
df_.columns.tolist()
# Out:
# ['ticker',
#  'time_published',
#  'news_date',
#  'effective_date',
#  'day0_date',
#  'day1_date',
#  'day0_close_stock',
#  'day1_close_stock',
#  'stock_return',
#  'spy_return',
#  'abnormal_return',
#  'ar_score',
#  'sentiment_score',
#  'category_score',
#  'impact_score',
#  'impact_tier',
#  'impact_direction',
#  'event_label',
#  'title',
#  'summary',
#  'source',
#  'overall_sentiment_label']

# %%
df_.day0_close_stock.isnull().sum()
# Out:
# np.int64(0)

# %%
df_.day0_close
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 457    150.809998
# 458    152.000000
# 459    158.619995
# 460    156.669998
# 461    156.669998
# Name: day0_close, Length: 462, dtype: float64

# %%
df_['event_label'].unique()
# Out:
# array(['Regulatory/Legal', 'Product Launch', 'Market Movement',
#        'Earnings', 'Other', 'Merger/Acquisition', 'Economic Data',
#        'Leadership Change', 'Fed Monetary Policy'], dtype=object)

# %%
df_.columns.tolist()
# Out:
# ['ticker',
#  'time_published',
#  'news_date',
#  'effective_date',
#  'day0_date',
#  'day1_date',
#  'day0_close_stock',
#  'day1_close_stock',
#  'stock_return',
#  'spy_return',
#  'abnormal_return',
#  'ar_score',
#  'sentiment_score',
#  'category_score',
#  'impact_score',
#  'impact_tier',
#  'impact_direction',
#  'event_label',
#  'title',
#  'summary',
#  'source',
#  'overall_sentiment_label']

# %%
print("Shape:", df_.shape)
print("\nDtypes:\n", df_.dtypes)
print("\nNulls:\n", df_.isnull().sum())
print("\nDuplicates:", df_.duplicated(subset=["ticker", "title", "time_published"]).sum())
print("\nUnique event_labels:", df_["event_label"].unique())
print("\nSentiment score range:", df_["sentiment_score"].min(), "→", df_["sentiment_score"].max())
print("\nSample:\n", df_.head(3).to_string())
# Out:
# Shape: (461, 22)
#
# Dtypes:
#  ticker                      object
# time_published              object
# news_date                   object
# effective_date              object
# day0_date                   object
# day1_date                   object
# day0_close_stock           float64
# day1_close_stock           float64
# stock_return               float64
# spy_return                 float64
# abnormal_return            float64
# ar_score                   float64
# sentiment_score            float64
# category_score             float64
# impact_score               float64
# impact_tier                 object
# impact_direction            object
# event_label                 object
# title                       object
# summary                     object
# source                      object
# overall_sentiment_label     object
# dtype: object
#
# Nulls:
#  ticker                     0
# time_published             0
# news_date                  0
# effective_date             0
# ...

# %% [markdown]
# # **Clean**

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\DELL\Documents\MLOPS\Finance News Intelligent System\Financial-News-Intelligent-System---Enterprise-Level\artifacts\transform\impact_score\impact_scores.csv")

# %%
data.head()
# Out:
#   ticker             time_published   news_date effective_date   day0_date  \
# 0   TSLA  2025-03-20 03:51:32+00:00  2025-03-20     2025-03-20  2025-03-20
# 1    JNJ  2025-03-31 03:12:41+00:00  2025-03-31     2025-03-31  2025-03-31
# 2    UNH  2025-02-20 04:33:21+00:00  2025-02-20     2025-02-20  2025-02-20
# 3   TSLA  2025-03-20 14:09:35+00:00  2025-03-20     2025-03-20  2025-03-20
# 4   TSLA  2025-03-21 03:51:22+00:00  2025-03-21     2025-03-21  2025-03-21
#
#     day1_date  day0_close_stock  day1_close_stock  stock_return  spy_return  \
# 0  2025-03-21        236.259995        248.710007      0.052696    0.000330
# 1  2025-04-01        161.344620        149.095901     -0.075916    0.002824
# 2  2025-02-21        486.561798        451.698059     -0.071653   -0.017104
# 3  2025-03-21        236.259995        248.710007      0.052696    0.000330
# 4  2025-03-24        248.710007        278.390015      0.119336    0.017908
#
# ...
