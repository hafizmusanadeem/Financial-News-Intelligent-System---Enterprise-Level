# %%
import pandas as pd

# %%
df = pd.read_csv('finnhub_data.csv')

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
len(df.columns.tolist())
# Out:
# 9

# %%
df.drop(columns = ['category'], inplace = True )

# %%
df.loc[224, ['summary', 'datetime']]
# Out:
# summary     TSMC (NYSE:TSM) reported preliminary Q1 2026 r...
# datetime                                  2026-04-12 07:08:57
# Name: 224, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  744 non-null    datetime64[ns]
#  1   headline  744 non-null    object
#  2   id        744 non-null    int64
#  3   image     666 non-null    object
#  4   related   744 non-null    object
#  5   source    744 non-null    object
#  6   summary   738 non-null    object
#  7   url       744 non-null    object
#  8   ticker    744 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 52.4+ KB

# %%
df['summary']
# Out:
# 0      While rival tech giants pour hundreds of billi...
# 1      Money News Network (MNN), a leading podcast-fi...
# 2      NVIDIA rides AI-driven demand and data center ...
# 3      (Bloomberg) -- Apple Inc. and Google have cont...
# 4      (Bloomberg) -- Apple Inc. and Google have cont...
#                              ...
# 739    Can Oracle (NYSE: ORCL) stock reach $300 in th...
# 740    Synopsys, Inc. (NASDAQ:SNPS) is one of the 10 ...
# 741    Microsoft Corporation (NASDAQ:MSFT) is one of ...
# 742    NBIS' AI cloud boom pushes pipeline toward $4B...
# 743    Microsoft Corp (NASDAQ:MSFT) shares are moving...
# Name: summary, Length: 744, dtype: object

# %%
df.shape
# Out:
# (744, 9)
